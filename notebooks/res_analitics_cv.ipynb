# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = pd.read_pickle('./results/best_hist_cv.pkl')

# %%
x = x.loc[x.sample_size == 30000]

# %%
x['val_loss']
# Out:
# ([4.51030158996582,
#   4.50154972076416,
#   4.45453405380249,
#   4.388837814331055,
#   4.325902938842773,
#   4.244560718536377,
#   4.157115459442139,
#   4.148380279541016,
#   4.128056526184082,
#   4.1390814781188965,
#   4.1063666343688965,
#   4.101865768432617,
#   4.104058742523193,
#   4.084851264953613,
#   4.068965435028076,
#   4.052583694458008,
#   4.057265281677246,
#   4.028957843780518,
#   4.023655414581299,
#   4.003221035003662,
#   3.9915037155151367,
#   3.949706554412842,
#   3.9505043029785156,
#   3.9247424602508545,
#   3.9163780212402344,
#   3.9174444675445557,
#   3.898698329925537,
#   3.9054114818573,
#   3.885073184967041,
#   3.877394199371338,
#   3.8772642612457275,
#   3.869790554046631,
#   3.8706440925598145,
#   3.8652665615081787,
#   3.853036403656006,
#   3.876375913619995,
#   3.8441383838653564,
#   3.8513946533203125,
#   3.8407225608825684,
#   3.849457263946533,
#   3.8301613330841064,
#   3.831251382827759,
#   3.828291654586792,
# ...

# %%
plt.plot(x['loss'].values[0], label="train_loss")
plt.plot(x['val_loss'].values[0], label="val_loss")

plt.legend(loc=2)
